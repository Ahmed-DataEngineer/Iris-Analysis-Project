# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv("iris.csv")
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.set(style="whitegrid")
sns.scatterplot(x="sepal.length",y="petal.length",hue="variety",style="variety",data=data)
plt.show()

# %%
sns.set(style="whitegrid")
sns.scatterplot(x="sepal.width",y="petal.width",hue="variety",style="variety",data=data)
plt.show()

# %%
sns.set(style="whitegrid")
sns.scatterplot(x="sepal.length",y="petal.width",hue="variety",style="variety",data=data)
plt.show()

# %%
sns.set(style="whitegrid")
sns.scatterplot(x="sepal.width",y="petal.length",hue="variety",style="variety",data=data)
plt.show()
